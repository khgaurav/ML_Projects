# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim

df = pd.read_csv('diabetes.csv')


X = df.drop(columns=['Class']).values
y = (df['Class'] == 'positive').astype(float).values  # positive -> 1, negative -> 0

X = torch.tensor(X, dtype=torch.float32)
y = torch.tensor(y, dtype=torch.float32).reshape(-1, 1)
df.shape
# Out:
# (768, 8)

# %%
# Define the model (7 input features in this dataset)
model = nn.Sequential(
    nn.Linear(7, 12),
    nn.ReLU(),
    nn.Linear(12, 8),
    nn.ReLU(),
    nn.Linear(8, 1),
    nn.Sigmoid()
)

# model = nn.Sequential(
#     nn.Linear(7, 16),
#     nn.Sigmoid()
# )

print(model)
# Out:
# Sequential(
#   (0): Linear(in_features=7, out_features=12, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=12, out_features=8, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=8, out_features=1, bias=True)
#   (5): Sigmoid()
# )

# %%
#THis part to Run only the first layer directly

with torch.no_grad():
    out1 = model[0](X)

print(out1.shape)             # torch.Size([768, 12]) -> 16 values per patient
print(out1[0])                # first patient's 16 raw outputs
# Out:
# torch.Size([768, 12])
# tensor([ -1.5348,  -0.5495, -51.6470,  62.1181, -17.2785, -56.1523,  26.5639,
#         -30.0714, -12.2996, -27.7183,  -8.7392,  19.2497])

# %%
# First layer directly with  ReLU

with torch.no_grad():
    out1_relu = model[:2](X)  # Linear(7,12) -> ReLU
print(out1_relu[0])           # same 12 values but negatives clipped to 0
# Out:
# tensor([ 0.0000,  0.0000,  0.0000, 62.1181,  0.0000,  0.0000, 26.5639,  0.0000,
#          0.0000,  0.0000,  0.0000, 19.2497])

# %%
# one layer at a time

x = X[0:1]                    # first patient (keep 2D shape: [1, 7])

with torch.no_grad():
    for layer in model:
        x = layer(x)
        print(f"{layer.__class__.__name__:>8}: {x.numpy().round(3)}")
# Out:
#   Linear: [[ -1.535  -0.55  -51.647  62.118 -17.279 -56.152  26.564 -30.071 -12.3
#   -27.718  -8.739  19.25 ]]
#     ReLU: [[ 0.     0.     0.    62.118  0.     0.    26.564  0.     0.     0.
#    0.    19.25 ]]
#   Linear: [[ 3.036  4.559 19.881 -7.493 -1.575 -2.066 21.051 -1.512]]
#     ReLU: [[ 3.036  4.559 19.881  0.     0.     0.    21.051  0.   ]]
#   Linear: [[-3.97]]
#  Sigmoid: [[0.019]]

# %%
# Forward Pass
with torch.no_grad():
    out_relu = model[:2](X)   # runs model[0] (Linear) then model[1] (ReLU)

print(out_relu.shape)         # torch.Size([768, 12])
print(out_relu[0])            # first patient's 12 activations after ReLU
# Out:
# torch.Size([768, 12])
# tensor([ 0.0000,  0.0000,  0.0000, 62.1181,  0.0000,  0.0000, 26.5639,  0.0000,
#          0.0000,  0.0000,  0.0000, 19.2497])

# %%
# Train the model
loss_fn = nn.BCELoss()  # binary cross entropy
optimizer = optim.Adam(model.parameters(), lr=0.009)

n_epochs = 400
batch_size = 32

# %%
for epoch in range(n_epochs):
    for i in range(0, len(X), batch_size):
        Xbatch = X[i:i + batch_size]
        y_pred = model(Xbatch)
        ybatch = y[i:i + batch_size]
        loss = loss_fn(y_pred, ybatch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Finished epoch {epoch}, latest loss {loss}')
# Out:
# Finished epoch 0, latest loss 0.7076102495193481
# Finished epoch 1, latest loss 0.7176728844642639
# Finished epoch 2, latest loss 0.6914642453193665
# Finished epoch 3, latest loss 0.669583797454834
# Finished epoch 4, latest loss 0.6459158062934875
# Finished epoch 5, latest loss 0.6490514278411865
# Finished epoch 6, latest loss 0.6458113789558411
# Finished epoch 7, latest loss 0.6471644639968872
# Finished epoch 8, latest loss 0.6417903900146484
# Finished epoch 9, latest loss 0.6418166756629944
# Finished epoch 10, latest loss 0.6401657462120056
# Finished epoch 11, latest loss 0.6429283618927002
# Finished epoch 12, latest loss 0.6390978693962097
# Finished epoch 13, latest loss 0.6628899574279785
# Finished epoch 14, latest loss 0.6391123533248901
# Finished epoch 15, latest loss 0.6277983784675598
# Finished epoch 16, latest loss 0.6252766847610474
# Finished epoch 17, latest loss 0.6188130974769592
# Finished epoch 18, latest loss 0.6130012273788452
# Finished epoch 19, latest loss 0.6239320635795593
# Finished epoch 20, latest loss 0.5909053087234497
# Finished epoch 21, latest loss 0.6398119926452637
# Finished epoch 22, latest loss 0.589762806892395
# Finished epoch 23, latest loss 0.5826413631439209
# Finished epoch 24, latest loss 0.5613002181053162
# Finished epoch 25, latest loss 0.5623490810394287
# Finished epoch 26, latest loss 0.5463998317718506
# Finished epoch 27, latest loss 0.5475034713745117
# Finished epoch 28, latest loss 0.610592246055603
# Finished epoch 29, latest loss 0.5937084555625916
# Finished epoch 30, latest loss 0.5735874176025391
# Finished epoch 31, latest loss 0.573548436164856
# Finished epoch 32, latest loss 0.5606144070625305
# Finished epoch 33, latest loss 0.5750401020050049
# Finished epoch 34, latest loss 0.5619500875473022
# Finished epoch 35, latest loss 0.5580385327339172
# Finished epoch 36, latest loss 0.5646691918373108
# Finished epoch 37, latest loss 0.5816817879676819
# Finished epoch 38, latest loss 0.5841140747070312
# Finished epoch 39, latest loss 0.592981219291687
# Finished epoch 40, latest loss 0.6001457571983337
# Finished epoch 41, latest loss 0.6096088886260986
# Finished epoch 42, latest loss 0.5908987522125244
# Finished epoch 43, latest loss 0.5571789741516113
# Finished epoch 44, latest loss 0.5422449707984924
# Finished epoch 45, latest loss 0.5202237367630005
# Finished epoch 46, latest loss 0.504120409488678
# Finished epoch 47, latest loss 0.4978393018245697
# Finished epoch 48, latest loss 0.5037750005722046
# Finished epoch 49, latest loss 0.4909081757068634
# Finished epoch 50, latest loss 0.4867715835571289
# Finished epoch 51, latest loss 0.47847554087638855
# Finished epoch 52, latest loss 0.46844980120658875
# Finished epoch 53, latest loss 0.46812161803245544
# Finished epoch 54, latest loss 0.46482163667678833
# Finished epoch 55, latest loss 0.46253857016563416
# Finished epoch 56, latest loss 0.45479995012283325
# Finished epoch 57, latest loss 0.4572538435459137
# Finished epoch 58, latest loss 0.450302392244339
# Finished epoch 59, latest loss 0.45554500818252563
# Finished epoch 60, latest loss 0.4518255591392517
# Finished epoch 61, latest loss 0.4434117078781128
# Finished epoch 315, latest loss 0.38275617361068726
# Finished epoch 316, latest loss 0.3957920968532562
# Finished epoch 317, latest loss 0.3895954489707947
# Finished epoch 318, latest loss 0.379825621843338
# Finished epoch 319, latest loss 0.39683887362480164
# Finished epoch 320, latest loss 0.3926779627799988
# Finished epoch 321, latest loss 0.42152470350265503
# Finished epoch 322, latest loss 0.41572266817092896
# Finished epoch 323, latest loss 0.4022710621356964
# Finished epoch 324, latest loss 0.39115971326828003
# Finished epoch 325, latest loss 0.3992927074432373
# Finished epoch 326, latest loss 0.37579554319381714
# Finished epoch 327, latest loss 0.3957841694355011
# Finished epoch 328, latest loss 0.3797593414783478
# Finished epoch 329, latest loss 0.3867829442024231
# Finished epoch 330, latest loss 0.39055293798446655
# Finished epoch 331, latest loss 0.41259318590164185
# Finished epoch 332, latest loss 0.4050012230873108
# Finished epoch 333, latest loss 0.3708556890487671
# Finished epoch 334, latest loss 0.42448386549949646
# Finished epoch 335, latest loss 0.38026294112205505
# Finished epoch 336, latest loss 0.42015546560287476
# Finished epoch 337, latest loss 0.37908124923706055
# Finished epoch 338, latest loss 0.37999483942985535
# Finished epoch 339, latest loss 0.38153403997421265
# Finished epoch 340, latest loss 0.36639779806137085
# Finished epoch 341, latest loss 0.3846697211265564
# Finished epoch 342, latest loss 0.4137142300605774
# Finished epoch 343, latest loss 0.37355974316596985
# Finished epoch 344, latest loss 0.4093930125236511
# Finished epoch 345, latest loss 0.4526326060295105
# Finished epoch 346, latest loss 0.38004934787750244
# Finished epoch 347, latest loss 0.4078584611415863
# Finished epoch 348, latest loss 0.4064111113548279
# Finished epoch 349, latest loss 0.3847205936908722
# Finished epoch 350, latest loss 0.3982381820678711
# Finished epoch 351, latest loss 0.3799377381801605
# Finished epoch 352, latest loss 0.38778531551361084
# Finished epoch 353, latest loss 0.3836056888103485
# Finished epoch 354, latest loss 0.3800267279148102
# Finished epoch 355, latest loss 0.3839254081249237
# Finished epoch 356, latest loss 0.40376150608062744
# Finished epoch 357, latest loss 0.3768405616283417
# Finished epoch 358, latest loss 0.4006010890007019
# Finished epoch 359, latest loss 0.36773499846458435
# Finished epoch 360, latest loss 0.37542515993118286
# Finished epoch 361, latest loss 0.4310227036476135
# Finished epoch 362, latest loss 0.3948720693588257
# Finished epoch 363, latest loss 0.3745071291923523
# Finished epoch 364, latest loss 0.35710757970809937
# Finished epoch 365, latest loss 0.4002910256385803
# Finished epoch 366, latest loss 0.3724978566169739
# Finished epoch 367, latest loss 0.3529319763183594
# Finished epoch 368, latest loss 0.36888331174850464
# Finished epoch 369, latest loss 0.34398984909057617
# Finished epoch 370, latest loss 0.4183998107910156
# Finished epoch 371, latest loss 0.38416457176208496
# Finished epoch 372, latest loss 0.38375699520111084
# Finished epoch 373, latest loss 0.35781317949295044
# Finished epoch 374, latest loss 0.36718863248825073
# Finished epoch 375, latest loss 0.3584948480129242
# Finished epoch 376, latest loss 0.36895328760147095
# Finished epoch 377, latest loss 0.3730470538139343
# Finished epoch 378, latest loss 0.411797434091568
# Finished epoch 379, latest loss 0.38988107442855835
# Finished epoch 380, latest loss 0.3860800564289093
# Finished epoch 381, latest loss 0.3937450349330902
# Finished epoch 382, latest loss 0.3814362585544586
# Finished epoch 383, latest loss 0.37449732422828674
# Finished epoch 384, latest loss 0.3920475244522095
# Finished epoch 385, latest loss 0.3729541301727295
# Finished epoch 386, latest loss 0.3704322576522827
# Finished epoch 387, latest loss 0.3298282325267792
# Finished epoch 388, latest loss 0.361882746219635
# Finished epoch 389, latest loss 0.373380571603775
# Finished epoch 390, latest loss 0.3317033350467682
# Finished epoch 391, latest loss 0.38268619775772095
# Finished epoch 392, latest loss 0.37136077880859375
# Finished epoch 393, latest loss 0.383102148771286
# Finished epoch 394, latest loss 0.3758167326450348
# Finished epoch 395, latest loss 0.4132837653160095
# Finished epoch 396, latest loss 0.3785942792892456
# Finished epoch 397, latest loss 0.39494433999061584
# Finished epoch 398, latest loss 0.37492311000823975
# Finished epoch 399, latest loss 0.35880348086357117

# %%
def train_with_lr(lr, n_epochs=20, batch_size=10):
    torch.manual_seed(0)
    m = nn.Sequential(nn.Linear(7,12), nn.ReLU(), nn.Linear(12,8), nn.ReLU(),
                      nn.Linear(8,1), nn.Sigmoid())
    opt = optim.Adam(m.parameters(), lr=lr)
    loss_fn = nn.BCELoss()

    history = []
    for epoch in range(n_epochs):
        epoch_loss, n_batches = 0.0, 0
        for i in range(0, len(X), batch_size):
            y_pred = m(X[i:i+batch_size])
            loss = loss_fn(y_pred, y[i:i+batch_size])
            opt.zero_grad(); loss.backward(); opt.step()
            epoch_loss += loss.item(); n_batches += 1
        history.append(epoch_loss / n_batches)

    with torch.no_grad():
        accuracy = (m(X).round() == y).float().mean().item()
    return history, accuracy

# %%
results = {lr: train_with_lr(lr) for lr in [5.0, 1e-7, 0.001]}

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
for lr, (history, _) in results.items():
    plt.plot(range(1, len(history)+1), history, marker='o', label=f'lr = {lr:g}')
plt.xlabel('Epoch'); plt.ylabel('Mean training loss (BCE)')
plt.yscale('log'); plt.legend(); plt.grid(alpha=0.3)
plt.savefig('lr_comparison.png', dpi=150, bbox_inches='tight')
plt.show()

# %%
# Compute accuracy (no_grad is optional)
with torch.no_grad():
    y_pred = model(X)
accuracy = (y_pred.round() == y).float().mean()
print(f"Accuracy {accuracy}")
# Out:
# Accuracy 0.7981770634651184

# %%
# 2nd model
model = nn.Sequential(
    nn.Linear(7, 16),
    nn.ReLU(),
    nn.Linear(16, 1),
    nn.Sigmoid()
)
# Train the model
loss_fn = nn.BCELoss()  # binary cross entropy
optimizer = optim.Adam(model.parameters(), lr=0.009)

n_epochs = 400
batch_size = 32
for epoch in range(n_epochs):
    for i in range(0, len(X), batch_size):
        Xbatch = X[i:i + batch_size]
        y_pred = model(Xbatch)
        ybatch = y[i:i + batch_size]
        loss = loss_fn(y_pred, ybatch)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Finished epoch {epoch}, latest loss {loss}')

# Compute accuracy (no_grad is optional)
with torch.no_grad():
    y_pred = model(X)
accuracy = (y_pred.round() == y).float().mean()
print(f"Accuracy {accuracy}")
# Out:
# Finished epoch 0, latest loss 0.7386340498924255
# Finished epoch 1, latest loss 0.7542474865913391
# Finished epoch 2, latest loss 0.6272645592689514
# Finished epoch 3, latest loss 0.6183657646179199
# Finished epoch 4, latest loss 0.6089551448822021
# Finished epoch 5, latest loss 0.6173099875450134
# Finished epoch 6, latest loss 0.6216903328895569
# Finished epoch 7, latest loss 0.62846839427948
# Finished epoch 8, latest loss 0.6331084370613098
# Finished epoch 9, latest loss 0.6297159194946289
# Finished epoch 10, latest loss 0.6195446252822876
# Finished epoch 11, latest loss 0.6130302548408508
# Finished epoch 12, latest loss 0.5959227085113525
# Finished epoch 13, latest loss 0.5968080163002014
# Finished epoch 14, latest loss 0.6011265516281128
# Finished epoch 15, latest loss 0.5899447798728943
# Finished epoch 16, latest loss 0.6064735054969788
# Finished epoch 17, latest loss 0.5867899656295776
# Finished epoch 18, latest loss 0.5858486294746399
# Finished epoch 19, latest loss 0.5923343896865845
# Finished epoch 20, latest loss 0.5803690552711487
# Finished epoch 21, latest loss 0.5755983591079712
# Finished epoch 22, latest loss 0.5949913263320923
# Finished epoch 23, latest loss 0.5785461068153381
# Finished epoch 24, latest loss 0.5822149515151978
# Finished epoch 25, latest loss 0.5730894804000854
# Finished epoch 26, latest loss 0.5703397989273071
# Finished epoch 27, latest loss 0.5661623477935791
# Finished epoch 28, latest loss 0.5635265707969666
# Finished epoch 29, latest loss 0.5624942779541016
# Finished epoch 30, latest loss 0.558467447757721
# Finished epoch 31, latest loss 0.5561861991882324
# Finished epoch 32, latest loss 0.5584916472434998
# Finished epoch 33, latest loss 0.5504441261291504
# Finished epoch 34, latest loss 0.5490166544914246
# Finished epoch 35, latest loss 0.5470823049545288
# Finished epoch 36, latest loss 0.547624409198761
# Finished epoch 37, latest loss 0.541918933391571
# Finished epoch 38, latest loss 0.5426301956176758
# Finished epoch 39, latest loss 0.539600133895874
# Finished epoch 40, latest loss 0.543250322341919
# Finished epoch 41, latest loss 0.5384435653686523
# Finished epoch 42, latest loss 0.5430266857147217
# Finished epoch 43, latest loss 0.5388431549072266
# Finished epoch 44, latest loss 0.5401943922042847
# Finished epoch 45, latest loss 0.5381431579589844
# Finished epoch 46, latest loss 0.5363377332687378
# Finished epoch 47, latest loss 0.5372315645217896
# Finished epoch 48, latest loss 0.531693696975708
# Finished epoch 49, latest loss 0.5345010161399841
# Finished epoch 50, latest loss 0.5283117294311523
# Finished epoch 51, latest loss 0.5365981459617615
# Finished epoch 52, latest loss 0.5310984253883362
# Finished epoch 53, latest loss 0.5264118313789368
# Finished epoch 54, latest loss 0.530811071395874
# Finished epoch 55, latest loss 0.5316537022590637
# Finished epoch 56, latest loss 0.531002938747406
# Finished epoch 57, latest loss 0.5252904295921326
# Finished epoch 58, latest loss 0.5320087671279907
# Finished epoch 59, latest loss 0.5253705978393555
# Finished epoch 60, latest loss 0.533936083316803
# Finished epoch 61, latest loss 0.5252268314361572
# Finished epoch 62, latest loss 0.5256054401397705
# Finished epoch 63, latest loss 0.5286652445793152
# Finished epoch 64, latest loss 0.5269528031349182
# Finished epoch 65, latest loss 0.5268552899360657
# Finished epoch 66, latest loss 0.5324690937995911
# Finished epoch 67, latest loss 0.5242518186569214
# Finished epoch 68, latest loss 0.5281568765640259
# Finished epoch 69, latest loss 0.5214537382125854
# Finished epoch 70, latest loss 0.5298468470573425
# Finished epoch 71, latest loss 0.5226701498031616
# Finished epoch 72, latest loss 0.5330957770347595
# Finished epoch 73, latest loss 0.5229469537734985
# Finished epoch 74, latest loss 0.5305168628692627
# Finished epoch 75, latest loss 0.5239261388778687
# Finished epoch 76, latest loss 0.5321402549743652
# Finished epoch 77, latest loss 0.5216841697692871
# Finished epoch 78, latest loss 0.5313461422920227
# Finished epoch 79, latest loss 0.5371357798576355
# Finished epoch 80, latest loss 0.5510375499725342
# Finished epoch 81, latest loss 0.5434737801551819
# Finished epoch 82, latest loss 0.5459010004997253
# Finished epoch 83, latest loss 0.5416634678840637
# Finished epoch 84, latest loss 0.5474575757980347
# Finished epoch 85, latest loss 0.5417045950889587
# Finished epoch 86, latest loss 0.5435546636581421
# Finished epoch 87, latest loss 0.5470083951950073
# Finished epoch 88, latest loss 0.5749929547309875
# Finished epoch 89, latest loss 0.6097275018692017
# Finished epoch 90, latest loss 0.5827963948249817
# Finished epoch 91, latest loss 0.5725095868110657
# Finished epoch 92, latest loss 0.5866105556488037
# Finished epoch 93, latest loss 0.5795050859451294
# Finished epoch 94, latest loss 0.5669506192207336
# Finished epoch 95, latest loss 0.5594457387924194
# Finished epoch 96, latest loss 0.556919515132904
# Finished epoch 97, latest loss 0.5631718635559082
# Finished epoch 98, latest loss 0.5568923354148865
# Finished epoch 99, latest loss 0.5428956747055054
# Finished epoch 100, latest loss 0.5491901636123657
# Finished epoch 101, latest loss 0.5521833300590515
# Finished epoch 102, latest loss 0.5428706407546997
# Finished epoch 103, latest loss 0.5427249670028687
# Finished epoch 104, latest loss 0.5381313562393188
# Finished epoch 105, latest loss 0.5445774793624878
# Finished epoch 106, latest loss 0.5434794425964355
# Finished epoch 107, latest loss 0.5365967750549316
# Finished epoch 108, latest loss 0.5412494540214539
# Finished epoch 109, latest loss 0.5416361689567566
# Finished epoch 110, latest loss 0.5368677377700806
# Finished epoch 111, latest loss 0.5323972702026367
# Finished epoch 112, latest loss 0.5326477885246277
# Finished epoch 113, latest loss 0.5389190912246704
# Finished epoch 114, latest loss 0.5323677062988281
# Finished epoch 115, latest loss 0.5250018835067749
# Finished epoch 116, latest loss 0.5288135409355164
# Finished epoch 117, latest loss 0.5316889882087708
# Finished epoch 118, latest loss 0.5263214707374573
# Finished epoch 119, latest loss 0.5231879949569702
# Finished epoch 120, latest loss 0.5185801982879639
# Finished epoch 121, latest loss 0.5311496257781982
# Finished epoch 122, latest loss 0.5229529738426208
# Finished epoch 123, latest loss 0.5228169560432434
# Finished epoch 124, latest loss 0.5233827829360962
# Finished epoch 251, latest loss 0.4620512127876282
# Finished epoch 252, latest loss 0.47463735938072205
# Finished epoch 253, latest loss 0.46508583426475525
# Finished epoch 254, latest loss 0.4624442458152771
# Finished epoch 255, latest loss 0.4638117253780365
# Finished epoch 256, latest loss 0.46066150069236755
# Finished epoch 257, latest loss 0.4647037386894226
# Finished epoch 258, latest loss 0.46622535586357117
# Finished epoch 259, latest loss 0.45200738310813904
# Finished epoch 260, latest loss 0.4671417474746704
# Finished epoch 261, latest loss 0.4573424458503723
# Finished epoch 262, latest loss 0.4609070122241974
# Finished epoch 263, latest loss 0.46194538474082947
# Finished epoch 264, latest loss 0.46831485629081726
# Finished epoch 265, latest loss 0.45571744441986084
# Finished epoch 266, latest loss 0.47660699486732483
# Finished epoch 267, latest loss 0.4473687708377838
# Finished epoch 268, latest loss 0.48392075300216675
# Finished epoch 269, latest loss 0.4331851303577423
# Finished epoch 270, latest loss 0.4605692923069
# Finished epoch 271, latest loss 0.44301944971084595
# Finished epoch 272, latest loss 0.4511033594608307
# Finished epoch 273, latest loss 0.4456113874912262
# Finished epoch 274, latest loss 0.46063002943992615
# Finished epoch 275, latest loss 0.44815653562545776
# Finished epoch 276, latest loss 0.4503629505634308
# Finished epoch 277, latest loss 0.45859310030937195
# Finished epoch 278, latest loss 0.45394593477249146
# Finished epoch 279, latest loss 0.45326992869377136
# Finished epoch 280, latest loss 0.4441099166870117
# Finished epoch 281, latest loss 0.4533642828464508
# Finished epoch 282, latest loss 0.44182807207107544
# Finished epoch 283, latest loss 0.44750991463661194
# Finished epoch 284, latest loss 0.45594337582588196
# Finished epoch 285, latest loss 0.45385727286338806
# Finished epoch 286, latest loss 0.4531916677951813
# Finished epoch 287, latest loss 0.4504323899745941
# Finished epoch 288, latest loss 0.455585777759552
# Finished epoch 289, latest loss 0.4496750235557556
# Finished epoch 290, latest loss 0.4513497054576874
# Finished epoch 291, latest loss 0.4670080542564392
# Finished epoch 292, latest loss 0.444206178188324
# Finished epoch 293, latest loss 0.4546351432800293
# Finished epoch 294, latest loss 0.45128312706947327
# Finished epoch 295, latest loss 0.45777884125709534
# Finished epoch 296, latest loss 0.4431227445602417
# Finished epoch 297, latest loss 0.45536723732948303
# Finished epoch 298, latest loss 0.4496370255947113
# Finished epoch 299, latest loss 0.45554134249687195
# Finished epoch 300, latest loss 0.4487369954586029
# Finished epoch 301, latest loss 0.45477840304374695
# Finished epoch 302, latest loss 0.4382949471473694
# Finished epoch 303, latest loss 0.46415483951568604
# Finished epoch 304, latest loss 0.45290735363960266
# Finished epoch 305, latest loss 0.4615026116371155
# Finished epoch 306, latest loss 0.4497004449367523
# Finished epoch 307, latest loss 0.4442640244960785
# Finished epoch 308, latest loss 0.45446205139160156
# Finished epoch 309, latest loss 0.44104474782943726
# Finished epoch 310, latest loss 0.4403858184814453
# Finished epoch 311, latest loss 0.4458611011505127
# Finished epoch 312, latest loss 0.4409862160682678
# Finished epoch 313, latest loss 0.43467479944229126
# Finished epoch 314, latest loss 0.4368469715118408
# Finished epoch 378, latest loss 0.4201768934726715
# Finished epoch 379, latest loss 0.41247665882110596
# Finished epoch 380, latest loss 0.411761075258255
# Finished epoch 381, latest loss 0.4175700843334198
# Finished epoch 382, latest loss 0.4097215533256531
# Finished epoch 383, latest loss 0.4079000949859619
# Finished epoch 384, latest loss 0.41835731267929077
# Finished epoch 385, latest loss 0.41051870584487915
# Finished epoch 386, latest loss 0.41072195768356323
# Finished epoch 387, latest loss 0.4073905944824219
# Finished epoch 388, latest loss 0.4069574475288391
# Finished epoch 389, latest loss 0.4075988531112671
# Finished epoch 390, latest loss 0.4106781482696533
# Finished epoch 391, latest loss 0.4179345667362213
# Finished epoch 392, latest loss 0.41300341486930847
# Finished epoch 393, latest loss 0.4093099534511566
# Finished epoch 394, latest loss 0.42735081911087036
# Finished epoch 395, latest loss 0.41495609283447266
# Finished epoch 396, latest loss 0.40658819675445557
# Finished epoch 397, latest loss 0.4040151834487915
# Finished epoch 398, latest loss 0.4080701172351837
# Finished epoch 399, latest loss 0.40598827600479126
# Accuracy 0.7942708134651184

# %%
import matplotlib.pyplot as plt

def draw_network(layer_sizes, layer_labels=None, layer_colors=None,
                 node_r=0.28, x_gap=3.2, y_gap=0.85, save_as=None):
    """Draw a fully-connected neural network as circles and lines."""
    fig, ax = plt.subplots(figsize=(11, 7))
    ax.set_aspect('equal'); ax.axis('off')

    if layer_colors is None:
        layer_colors = ['#5DCAA5'] + ['#AFA9EC'] * (len(layer_sizes) - 2) + ['#F0997B']

    # Compute node positions (each layer vertically centered)
    positions = []
    for i, n in enumerate(layer_sizes):
        x = i * x_gap
        ys = [(j - (n - 1) / 2) * y_gap for j in range(n)]
        positions.append([(x, y) for y in ys])

    # Connections first (so circles draw on top)
    for a, b in zip(positions[:-1], positions[1:]):
        for (x1, y1) in a:
            for (x2, y2) in b:
                ax.plot([x1, x2], [y1, y2], color='gray',
                        linewidth=0.4, alpha=0.35, zorder=1)

    # Neurons
    for pts, color in zip(positions, layer_colors):
        for (x, y) in pts:
            ax.add_patch(plt.Circle((x, y), node_r, facecolor=color,
                                    edgecolor='#444', linewidth=0.6, zorder=2))

    # Labels above each layer
    if layer_labels:
        top = max(len(n) for n in positions) * 0  # noqa
        y_top = max(max(y for _, y in pts) for pts in positions) + 1.0
        for i, label in enumerate(layer_labels):
            ax.text(i * x_gap, y_top, label, ha='center', va='bottom',
                    fontsize=11, fontweight='bold')

    ax.autoscale()
    ax.margins(0.08)
    if save_as:
        fig.savefig(save_as, dpi=200, bbox_inches='tight')
    return fig, ax


if __name__ == '__main__':
    draw_network(
        layer_sizes=[7, 12, 8, 1],
        layer_labels=['Input\n7 features', 'Hidden 1\nReLU', 'Hidden 2\nReLU', 'Output\nSigmoid'],
        save_as='NN1.png'
    )
    draw_network(
        layer_sizes=[7, 16, 1],
        layer_labels=['Input\n7 features', 'Hidden 1\nReLU', 'Hidden 2\nReLU', 'Output\nSigmoid'],
        save_as='NN2.png'
    )
    print('saved')
# Out:
# saved
